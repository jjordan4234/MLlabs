# %% [markdown]
# ## Lab 1: Getting data from API's
#
# A great source of data and Pandas practice is getting data from the Internet. It is not going to come in a .csv file, though: It will be a stream of records, typically in XML (eXtensible Mark-up Language) or JSON (JavaScript Object Notation) format.
#
# We'll look at a very simple API and some useful code chunks for getting and analyzing data, and then you'll take a look at the APIs available from the Federal government as the main work for your lab.

# %% [markdown]
# ## API Queries
#
# The core programming skill of the activity is to learn to query an online Application Programmer Interface (API). It is a similar experience to browsing the Internet, and initial results can be displayed the web browser. When visiting a web page, the address bar typically contains something like
# $$
# \texttt{https://} \underbrace{\texttt{www.}}_{\text{World Wide Web subdomain}} \texttt{domain}. \underbrace{\texttt{tld}}_{\text{Top level domain}},
# $$
# where the https:// specifies the protocol, www. specifies the world-wide-web subdomain, the domain is the entity, and the top-level domain .tld is typically something like .com or .gov, but is increasingly varied as ICANN releases more TLD's into circulation.
#
# With an online API, the user instead enters a url that goes directly to an API subdomain
# $$
# \texttt{https://} \underbrace{\texttt{api.}}_{\text{Application programmer interface}} \texttt{domain.tld}/ \texttt{(the query)}
# $$
# or accesses REST services as
# $$
# \texttt{https://www.domain.tld} \underbrace{\texttt{/REST}}_{\text{Accesses REST services}}/ \texttt{(the query)}
# $$
# This accesses data on the domain's servers and returns the result directly to the user.
#
# The query itself is typically a string beginning with a question mark ?, followed by a series of expressions joined by ampersands &. For example,
#
# `?ProductType=Phone\&Manufacturer=Apple`
#
# passes a query requesting all records for which the product type is recorded as phone and the manufacturer is recorded as Apple. Some API's include date ranges and other, more complex requests.
#
# To get started, a simple warm-up is to use the API from saferproducts.gov, which has a simple and intuitive structure for queries, and the results are simple enough to look at in the browser. Typing this in the address bar in a browser should yield about thirty records:
#
#     https://www.saferproducts.gov/RestWebServices/Recall?format=json&ProductType=Phone
#
# with the first being, on this occasion:
#
#     "RecallID": 7856,
#     "RecallNumber": "16266",
#     "RecallDate": "2016-09-15T00:00:00",
#     "Description": "This recall involves the Samsung Galaxy Note7 smartphone sold before
#     September 15, 2016. The recalled devices have a 5.7 inch screen and were sold in the
#     following colors: black onyx, blue coral, gold platinum and silver titanium with a
#     matching stylus. Samsung is printed on the top front of the phone and Galaxy Note7
#     is printed on the back of the phone. To determine if your phone has been recalled,
#     locate the IMEI number on the back of the phone or the packaging, and enter the IMEI
#     number into the online registration site www.samsung.com or call Samsung toll-free
#     at 844-365-6197.",
#     "URL": "https://www.cpsc.gov/Recalls/2016/Samsung-Recalls-Galaxy-Note7-Smartphones",
#     "Title": "Samsung Recalls Galaxy Note7 Smartphones Due to Serious Fire and Burn Hazards",
#     "ConsumerContact": "Contact your wireless carrier or place of purchase, call Samsung
#     toll-free at 844-365-6197 anytime, or go online at www.samsung.com.",
#     "LastPublishDate": "2016-10-27T00:00:00"
#
# The query itself in this case is:
#
#     ?format=json&ProductType=Phone
#
# The quert requests all of the recalls in JavaScript Object Notation (json) format, where the `ProductType` variable is equal to `Phone`. In addition to `ProductType`, other options include:
#
#     RecallID,
#     RecallNumber,
#     RecallDateStart,
#     RecallDateEnd,
#     RecallURL,
#     LastPublishDateStart,
#     LastPublishDateEnd,
#     RecallTitle,
#     ConsumerContact,
#     RecallDescription,
#     ProductName,
#     ProductDescription,
#     ProductModel,
#     ProductType,
#     InconjunctionURL,
#     ImageURL,
#     Injury,
#     Manufacturer,
#     Retailer,
#     Importer,
#     Distributor,
#     ManufacturerCountry,
#     UPC,
#     Hazard,
#     Remedy,
#     RemedyOption
#
# **1. Practice writing queries using the saferproducts.gov API and your web browser.**

# %%
https://www.saferproducts.gov/RestWebServices/Recall?format=json&RecallNumber=1725
https://www.saferproducts.gov/RestWebServices/Recall?format=json&RemedyOptions='Refund'&HazardTypeID="3"

# %%
***streamlet***

# %% [markdown]
# ## Accessing API's with Python
#
# Anytime you use a computer to access resources on the Internet, you will likely run into problems. There are many options, but two with low coding overhead: The `requests` and `urrlib.requests` packages.
#
# The following code chunk uses the `requests` package to get the same kind of data that was being displayed in the browser, but in an interactive Python session:
#
#     import requests
#     url = 'https://www.saferproducts.gov/RestWebServices/' # Location of the API
#     query = 'Recall?format=json&ProductType=Exercise' # The query
#     header = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:124.0)
#         Gecko/20100101 Firefox/124.0'} # The user-agent to avoid being blocked
#     raw = requests.get(url+query,headers=header) # Query the database
#     data = raw.json() # Convert data from json to dictionary
#
# To make the code easier to read, it separates the url and the query into two different strings, then concatenates them in the GET request. This makes it easier to edit the query, as well as suggests a simple way to loop over a number of queries that might be sent to the same API.
#
# Many resources are designed to block access from particular kinds of users. In order to circumvent these obstacles, you can specify a `header` dictionary that presents the query to the server as coming from a hypothetical and common user. In this case, the header presents the query as coming from a Firefox browser from a Windows computer, rather than something like `python-requests/3.12.1`. This problem appears generally in scraping data from the web, and can grind the process to a halt. For whatever reason, I have been blocked and gotten 403 errors with the `requests` package, which motivated me to prepare a second alternative that seems more robust:
#
#     import urllib.request
#     import json
#     url = 'https://www.saferproducts.gov/RestWebServices/' # Location of the API
#     query = 'Recall?format=json&ProductType=Exercise' # The query
#     response = urllib.request.urlopen(url+query)
#     response_bytes = response.read()
#     data = json.loads(response_bytes) # Convert response to json
#     response.close()
#
# This is a bit more code and some steps are a bit less human-friendly, but seems to work a bit more reliably than `requests`.
#
# **2. Practice with the saferproducts.gov API and the above code in a notebook to see how API's work, in general.**

# %%
import urllib.request
import json
url = 'https://www.saferproducts.gov/RestWebServices/' # Location of the API
query = 'Recall?format=json&ProductType=Exercise' # The query
response = urllib.request.urlopen(url+query)
response_bytes = response.read()
data = json.loads(response_bytes) # Convert response to json
response.close()

# %% [markdown]
# ## Wrangling the Data
#
# Piping the data to Pandas is easy, because the preceding code chunk put the JSON data into a native Python dictionary, and the following converts it to a dataframe:
#
#     df = pd.DataFrame.from_dict(data)
#
# If the data is in raw XML or JSON format --- which might especially be true with other API's --- it would instead be \texttt{pd.read\_xml(data)} or \texttt{pd.read\_json(data)}. Ironing out these details in advance for other applications is a key part of the presentation for students, but having students resolve these issues as a component of group work or an assignment is a great way to help them mature as coding problem solvers by struggling with documentation and a well-defined problem.
#
# Unfortunately, there aren't many non-text fields in the \texttt{www.saferproducts.gov} data. However, there are a few fields of interest that can be tabulated and discussed, such as RemedyOptions and ManufacturerCountries:
#
#     df['RemedyOptions'].value_counts()
#
# with output
#
#     RemedyOptions
#     []                                                                               139
#     [{'Option': 'Repair'}]                                                            49
#     [{'Option': 'Replace'}]                                                           12
#     [{'Option': 'Refund'}]                                                             7
#     [{'Option': 'Replace'}, {'Option': 'Repair'}]                                      4
#     [{'Option': 'Refund'}, {'Option': 'Replace'}, {'Option': 'Repair'}]                1
#     [{'Option': 'Replace'}, {'Option': 'Refund'}]                                      1
#     [{'Option': 'Refund'}, {'Option': 'Repair'}]                                       1
#     [{'Option': 'Label'}]                                                              1
#     [{'Option': 'New Instructions'}, {'Option': 'Replace'}, {'Option': 'Refund'}]      1
#     Name: count, dtype: int64
#
# It's appropriate at this point to do some data cleaning, particularly by flattening dictionary entries. With response data that get converted from json to a dictionary, there are often values in the data frame that need to be flattened or unpacked. For example, some values are recorded as \texttt{ [$\{$'Country':'Canada'$\}$]}, or, worse, a dictionary with multiple entries: \texttt{[ $\{$ 'Option': 'Replace'$\}$, $\{$'Option': 'Repair'$\}$]  ] }. This can lead to problems when another package refuses to work with a lists of lists or doesn't know how to simplify a dictionary to data, and presents some conceptual questions when cleaning.
#
# A simple script to recursively collapse the dictionary entries into a single string is:
#
#     temp = df['RemedyOptions']
#     clean_values = []
#     for i in range(len(temp)):
#         if len(temp[i])>0:
#             values = []
#             for j in range(len(temp[i])):
#                 values.append(temp[i][j]['Option'] )
#             clean_values.append(values)
#         else:
#             clean_values.append('')
#     df['remedy'] = clean_values
#
# **3. Convert this code chunk into a function you can reuse to flatten dictionaries, or explain clearly the problems you run into while attempting to do so. Make some tables or plots.**

# %%
import pandas as pd

# %%
df = pd.DataFrame.from_dict(data)

# %%
def flatten_dicts(dataframe, column, key, new_column):
    temp = dataframe[column]
    clean_values = []
    
    for i in range(len(temp)):
        if len(temp[i])>0:
            values = []
            for j in range(len(temp[i])):
                values.append(temp[i][j][key])
            clean_values.append(values)
        else:
            clean_values.append('')
            
    dataframe[new_column] = clean_values

# %%
flatten_dicts(df, 'RemedyOptions', 'Option', 'remedy')

# %%
# Display the updated DataFrame
print("\nUpdated DataFrame with 'remedy' column:")
print(df)
# Out:
# Updated DataFrame with 'remedy' column:
#     RecallID RecallNumber           RecallDate  \
# 0       7832        16247  2016-08-23T00:00:00
# 1       6724        16742  2016-05-10T00:00:00
# 2       6488        15749  2015-08-25T00:00:00
# 3       6420        15735  2015-06-16T00:00:00
# 4       6398        15140  2015-05-20T00:00:00
# ..       ...          ...                  ...
# 86      4958        90117  1990-06-28T00:00:00
# 87      4957        90115  1990-06-21T00:00:00
# 88      4870        89091  1989-09-26T00:00:00
# 89      4796        88106  1988-11-29T00:00:00
# 90      4122        81026  1981-10-13T00:00:00
#
#                                           Description  \
# 0   This recall involves "Step-iT" activity wristb...
# 1   This recall involves the Olympic Decline free ...
# 2   This recall involves four models of exercise m...
# 3   This recall involves the Rogue Fitness Mobilit...
# 4   This recall involves Valor Fitness BF-38 Flat/...
# ..                                                ...
# 86  June 28, 1990 Release # 90-117 Spring Exercise...
# 87  June 21, 1990 Release # 90-115 Retrofit Progra...
# 88  Stair Climber Exercise Device Repair by Precor...
# 89  November 29, 1988 Release # 88-106 Repair Prog...
# 90  Seat Attachment Parts On Exercise Bikes Replac...
#
#                                                   URL  \
# 0   https://www.cpsc.gov/Recalls/2016/McDonalds-Re...
# 1   https://www.cpsc.gov/Recalls/2016/Cybex-Intern...
# 2   https://www.cpsc.gov/Recalls/2015/Cybex-Intern...
# 3   https://www.cpsc.gov/Recalls/2015/Coulter-Vent...
# 4   https://www.cpsc.gov/Recalls/2015/Valor-Athlet...
# ..                                                ...
# 86  https://www.cpsc.gov/Recalls/1990/Spring-Exerc...
# 87  https://www.cpsc.gov/Recalls/1990/Retrofit-Pro...
# 88  https://www.cpsc.gov/Recalls/1989/Amputation-R...
# 89  https://www.cpsc.gov/Recalls/1988/Repair-Progr...
# 90  https://www.cpsc.gov/Recalls/1981/Seat-Attachm...
#
#                                                 Title  \
# 0   McDonald’s Recalls “Step-iT” Activity Wristban...
# 1   Cybex International Recalls Decline Free Weigh...
# 2   Cybex International Recalls Arm Curl Machines ...
# 3   Coulter Ventures Recalls MobilityWOD Door Anch...
# 4   Valor Athletics Recalls Olympic Weight Bench d...
# ..                                                ...
# 86  Spring Exercisers Recalled; Breaking Springs, ...
# 87   Retrofit Program Announced For Spring Exercisers
# 88     Stair Climber Exercise Device Repair by Precor
# 89     Repair Program Announced For Stomach Exerciser
# 90  Seat Attachment Parts On Exercise Bikes Replac...
#
#                                       ConsumerContact      LastPublishDate  \
# 0   McDonald's at 800-244-6227 from 7 a.m. to 7 p....  2016-08-23T00:00:00
# 1   Cybex toll-free at 888-462-9239 from 8 a.m. to...  2016-05-10T00:00:00
# 2   Cybex International toll-free at 888-678-3846 ...  2015-08-25T00:00:00
# 3   Coulter toll-free at (844) 216-3846 from 9 a.m...  2015-06-16T00:00:00
# 4   Valor Fitness toll-free at (844) 277-1641 Mond...  2015-05-20T00:00:00
# ..                                                ...                  ...
# 86                                               None  2015-01-16T00:00:00
# 87                                               None  2015-01-15T00:00:00
# 88                                               None  2015-01-07T00:00:00
# 89                                               None  2015-01-06T00:00:00
# 90                                               None  2014-12-18T00:00:00
#
#                                              Products  \
# 0   [{'Name': 'Step-iT Activity Wristbands', 'Desc...
# 1   [{'Name': 'Decline free weight benches', 'Desc...
# 2   [{'Name': 'Arm Curl Machines', 'Description': ...
# 3   [{'Name': 'MobilityWOD Door Anchor', 'Descript...
# 4   [{'Name': 'Weight bench', 'Description': '', '...
# ..                                                ...
# 86  [{'Name': 'New Gym Stomach Eliminator exercise...
# 87  [{'Name': 'Rowing Action Exerciser spring exer...
# 88  [{'Name': 'Low Impact Climber stair climber ph...
# 89  [{'Name': 'Gut Buster stomach exercise devices...
# 90  [{'Name': 'Beacon stationary bicycles', 'Descr...
#
#                                        Inconjunctions  ...  \
# 0   [{'URL': 'http://healthycanadians.gc.ca/recall...  ...
# 1                                                  []  ...
# 2                                                  []  ...
# 3                                                  []  ...
# 4                                                  []  ...
# ..                                                ...  ...
# 86                                                 []  ...
# 87                                                 []  ...
# 88                                                 []  ...
# 89                                                 []  ...
# 90                                                 []  ...
#
#                                             Retailers  \
# 0   [{'Name': 'Distributed exclusively by McDonald...
# 1   [{'Name': 'Cybex direct sales force or its dis...
# 2   [{'Name': 'Cybex or its distributors directly ...
# 3   [{'Name': 'Rogue Fitness websites: www.roguefi...
# 4   [{'Name': 'Valorathleticsinc.com and Valorfitn...
# ..                                                ...
# 86                                                 []
# 87                                                 []
# 88                                                 []
# 89                                                 []
# 90                                                 []
#
#                                             Importers  \
# 0                                                  []
# 1                                                  []
# 2                                                  []
# 3                                                  []
# 4   [{'Name': 'Valor Athletics Inc., of St. Peters...
# ..                                                ...
# 86                                                 []
# 87                                                 []
# 88                                                 []
# 89                                                 []
# 90                                                 []
#
#                                          Distributors SoldAtLabel  \
# 0   [{'Name': 'McDonald's Corp., of Oakbrook, Ill....        None
# 1                                                  []        None
# 2                                                  []        None
# 3   [{'Name': 'Coulter Ventures LLC, dba Rogue Fit...        None
# 4                                                  []        None
# ..                                                ...         ...
# 86                                                 []        None
# 87                                                 []        None
# 88                                                 []        None
# 89                                                 []        None
# 90                                                 []        None
#
#              ManufacturerCountries ProductUPCs  \
# 0           [{'Country': 'China'}]          []
# 1   [{'Country': 'United States'}]          []
# 2   [{'Country': 'United States'}]          []
# 3           [{'Country': 'China'}]          []
# 4           [{'Country': 'China'}]          []
# ..                             ...         ...
# 86          [{'Country': 'Italy'}]          []
# 87                              []          []
# 88                              []          []
# 89                              []          []
# 90                              []          []
#
#                                               Hazards  \
# 0   [{'Name': 'The recalled wristbands can cause s...
# 1   [{'Name': 'The frame on the bench can collapse...
# 2   [{'Name': 'The swivel handles can break off fr...
# 3   [{'Name': 'The nylon strap can pull out from t...
# 4   [{'Name': 'The weld joining the front leg to t...
# ..                                                ...
# 86  [{'Name': 'Laceration', 'HazardType': '', 'Haz...
# 87                                                 []
# 88  [{'Name': 'Amputation', 'HazardType': '', 'Haz...
# 89                                                 []
# 90  [{'Name': 'Fall', 'HazardType': '', 'HazardTyp...
#
#                                              Remedies  \
# 0   [{'Name': 'Consumers should immediately take t...
# 1   [{'Name': 'Consumers should immediately stop u...
# 2   [{'Name': 'Consumers should immediately stop u...
# 3   [{'Name': 'Consumers should immediately stop u...
# 4   [{'Name': 'Consumers should immediately stop u...
# ..                                                ...
# 86                                                 []
# 87                                                 []
# 88                                                 []
# 89                                                 []
# 90                                                 []
#
#               RemedyOptions     remedy
# 0   [{'Option': 'Replace'}]  [Replace]
# 1   [{'Option': 'Replace'}]  [Replace]
# 2    [{'Option': 'Repair'}]   [Repair]
# 3    [{'Option': 'Refund'}]   [Refund]
# 4    [{'Option': 'Repair'}]   [Repair]
# ..                      ...        ...
# 86                       []
# 87                       []
# 88                       []
# 89                       []
# 90                       []
#
# [91 rows x 23 columns]

# %% [markdown]
# ## Dashboarding the Results (Optional)
#
# To complete the pipeline from data to product, we can use \texttt{streamlit} to quickly convert Python code into a web page that can be accessed locally. This can be done with essentially three lines of code: An import statement, a $.title()$ method call to set the page title, and an $.write()$ call to push the results to the page. Although relatively static, completing this step serves a pedogogical and psychological purpose: It pivots the students to thinking about how to communicate results to an audience, and how the project could become an ongoing endeavor rather than a single analytical exercise.
#
# The entire .py file to create the dashboard is
#
#     import pandas as pd
#     import requests
#     import streamlit as st
#     # Conduct analysis:
#     url = 'https://www.saferproducts.gov/RestWebServices/Recall'
#     query = '?format=json&RecallTitle=Gas'
#     header = {'User-Agent':
#               'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:124.0) Gecko/20100101 Firefox/124.0'}
#     raw = requests.get(url+query,headers=header)
#     data = raw.json()
#     df = pd.DataFrame.from_dict(data)
#     temp = df['RemedyOptions']
#     clean_values = []
#     for i in range(len(temp)):
#         if len(temp[i])>0:
#             values = []
#             for j in range(len(temp[i])):
#                 values.append(temp[i][j]['Option'] )
#             clean_values.append(values)
#         else:
#             clean_values.append('')
#     df['remedy'] = clean_values
#     remedy_counts = df['remedy'].value_counts()
#     # Create streamlit output:
#     st.title('Remedy Statistics')
#     st.write(remedy_counts)
#
# To create the web page, run the following at the command line:
#
#     streamlit run remedy.py
#
# This should convert the above analysis into a web page available from localhost.
#
# **4. Produce your own table or plot, and output it to streamlit.**

# %%
pip install streamlit
# Out:
# Collecting streamlit
#   Downloading streamlit-1.38.0-py2.py3-none-any.whl (8.7 MB)
#      |████████████████████████████████| 8.7 MB 777 kB/s eta 0:00:01     |████████████████████████▎       | 6.6 MB 777 kB/s eta 0:00:03
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in ./opt/anaconda3/lib/python3.8/site-packages (from streamlit) (4.12.2)
# Requirement already satisfied: tornado<7,>=6.0.3 in ./opt/anaconda3/lib/python3.8/site-packages (from streamlit) (6.1)
# Requirement already satisfied: numpy<3,>=1.20 in ./opt/anaconda3/lib/python3.8/site-packages (from streamlit) (1.24.4)
# Collecting altair<6,>=4.0
#   Downloading altair-5.4.1-py3-none-any.whl (658 kB)
#      |████████████████████████████████| 658 kB 29.7 MB/s eta 0:00:01
# Requirement already satisfied: cachetools<6,>=4.0 in ./opt/anaconda3/lib/python3.8/site-packages (from streamlit) (5.2.0)
# Requirement already satisfied: click<9,>=7.0 in ./opt/anaconda3/lib/python3.8/site-packages (from streamlit) (7.1.2)
# Collecting pyarrow>=7.0
#   Downloading pyarrow-17.0.0.tar.gz (1.1 MB)
#      |████████████████████████████████| 1.1 MB 20.8 MB/s eta 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Collecting blinker<2,>=1.0.0
#   Downloading blinker-1.8.2-py3-none-any.whl (9.5 kB)
# Requirement already satisfied: protobuf<6,>=3.20 in ./opt/anaconda3/lib/python3.8/site-packages (from streamlit) (4.21.5)
# Collecting requests<3,>=2.27
#   Downloading requests-2.32.3-py3-none-any.whl (64 kB)
#      |████████████████████████████████| 64 kB 6.5 MB/s  eta 0:00:01
# Collecting tenacity<9,>=8.1.0
#   Downloading tenacity-8.5.0-py3-none-any.whl (28 kB)
# Requirement already satisfied: toml<2,>=0.10.1 in ./opt/anaconda3/lib/python3.8/site-packages (from streamlit) (0.10.2)
# Collecting rich<14,>=10.14.0
#   Downloading rich-13.8.1-py3-none-any.whl (241 kB)
#      |████████████████████████████████| 241 kB 26.2 MB/s eta 0:00:01
# Collecting pydeck<1,>=0.8.0b4
#   Downloading pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
#      |████████████████████████████████| 6.9 MB 18.1 MB/s eta 0:00:01
# Collecting gitpython!=3.1.19,<4,>=3.0.7
#   Downloading GitPython-3.1.43-py3-none-any.whl (207 kB)
#      |████████████████████████████████| 207 kB 28.1 MB/s eta 0:00:01
# Requirement already satisfied: packaging<25,>=20 in ./opt/anaconda3/lib/python3.8/site-packages (from streamlit) (20.9)
# Requirement already satisfied: pandas<3,>=1.3.0 in ./opt/anaconda3/lib/python3.8/site-packages (from streamlit) (2.0.3)
# Requirement already satisfied: pillow<11,>=7.1.0 in ./opt/anaconda3/lib/python3.8/site-packages (from streamlit) (8.2.0)
# Requirement already satisfied: jinja2 in ./opt/anaconda3/lib/python3.8/site-packages (from altair<6,>=4.0->streamlit) (2.11.3)
# Requirement already satisfied: jsonschema>=3.0 in ./opt/anaconda3/lib/python3.8/site-packages (from altair<6,>=4.0->streamlit) (3.2.0)
# Collecting narwhals>=1.5.2
#   Downloading narwhals-1.8.1-py3-none-any.whl (166 kB)
#      |████████████████████████████████| 166 kB 29.4 MB/s eta 0:00:01
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 2.1 MB/s  eta 0:00:01
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Requirement already satisfied: six>=1.11.0 in ./opt/anaconda3/lib/python3.8/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (1.15.0)
# Requirement already satisfied: setuptools in ./opt/anaconda3/lib/python3.8/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (52.0.0.post20210125)
# Requirement already satisfied: pyrsistent>=0.14.0 in ./opt/anaconda3/lib/python3.8/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.17.3)
# Requirement already satisfied: attrs>=17.4.0 in ./opt/anaconda3/lib/python3.8/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (20.3.0)
# Requirement already satisfied: pyparsing>=2.0.2 in ./opt/anaconda3/lib/python3.8/site-packages (from packaging<25,>=20->streamlit) (2.4.7)
# Requirement already satisfied: pytz>=2020.1 in ./opt/anaconda3/lib/python3.8/site-packages (from pandas<3,>=1.3.0->streamlit) (2021.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./opt/anaconda3/lib/python3.8/site-packages (from pandas<3,>=1.3.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.1 in ./opt/anaconda3/lib/python3.8/site-packages (from pandas<3,>=1.3.0->streamlit) (2024.1)
# Requirement already satisfied: MarkupSafe>=0.23 in ./opt/anaconda3/lib/python3.8/site-packages (from jinja2->altair<6,>=4.0->streamlit) (1.1.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./opt/anaconda3/lib/python3.8/site-packages (from requests<3,>=2.27->streamlit) (1.26.4)
# Requirement already satisfied: certifi>=2017.4.17 in ./opt/anaconda3/lib/python3.8/site-packages (from requests<3,>=2.27->streamlit) (2020.12.5)
# Collecting charset-normalizer<4,>=2
#   Downloading charset_normalizer-3.3.2-cp38-cp38-macosx_10_9_x86_64.whl (121 kB)
#      |████████████████████████████████| 121 kB 30.2 MB/s eta 0:00:01
# Requirement already satisfied: idna<4,>=2.5 in ./opt/anaconda3/lib/python3.8/site-packages (from requests<3,>=2.27->streamlit) (2.10)
# Collecting markdown-it-py>=2.2.0
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#      |████████████████████████████████| 87 kB 6.4 MB/s  eta 0:00:01
# Collecting pygments<3.0.0,>=2.13.0
#   Downloading pygments-2.18.0-py3-none-any.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 13.3 MB/s eta 0:00:01
# Requirement already satisfied: mdurl~=0.1 in ./opt/anaconda3/lib/python3.8/site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.2)
# Building wheels for collected packages: pyarrow
#   Building wheel for pyarrow (PEP 517) ... error
#   ERROR: Command errored out with exit status 1:
#    command: /Users/johnjordan/opt/anaconda3/bin/python /Users/johnjordan/opt/anaconda3/lib/python3.8/site-packages/pip/_vendor/pep517/_in_process.py build_wheel /var/folders/30/n6z5zgm17kx9ygm_fjmcvg000000gn/T/tmp74fm7nwz
#        cwd: /private/var/folders/30/n6z5zgm17kx9ygm_fjmcvg000000gn/T/pip-install-jorszxx8/pyarrow_9979dd1976b9448e82f7ea6f6650732c
#   Complete output (347 lines):
#   running bdist_wheel
#   running build
#   running build_py
#   creating build/lib.macosx-10.9-x86_64-cpython-38/benchmarks
#   copying benchmarks/array_ops.py -> build/lib.macosx-10.9-x86_64-cpython-38/benchmarks
#   copying benchmarks/convert_builtins.py -> build/lib.macosx-10.9-x86_64-cpython-38/benchmarks
#   copying benchmarks/parquet.py -> build/lib.macosx-10.9-x86_64-cpython-38/benchmarks
#   copying benchmarks/io.py -> build/lib.macosx-10.9-x86_64-cpython-38/benchmarks
#   copying benchmarks/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-38/benchmarks
#   copying benchmarks/microbenchmarks.py -> build/lib.macosx-10.9-x86_64-cpython-38/benchmarks
#   copying benchmarks/convert_pandas.py -> build/lib.macosx-10.9-x86_64-cpython-38/benchmarks
#   copying benchmarks/common.py -> build/lib.macosx-10.9-x86_64-cpython-38/benchmarks
#   copying benchmarks/streaming.py -> build/lib.macosx-10.9-x86_64-cpython-38/benchmarks
#   creating build/lib.macosx-10.9-x86_64-cpython-38/scripts
#   copying scripts/test_imports.py -> build/lib.macosx-10.9-x86_64-cpython-38/scripts
#   copying scripts/test_leak.py -> build/lib.macosx-10.9-x86_64-cpython-38/scripts
#   copying scripts/run_emscripten_tests.py -> build/lib.macosx-10.9-x86_64-cpython-38/scripts
#   creating build/lib.macosx-10.9-x86_64-cpython-38/pyarrow
#   copying pyarrow/orc.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow
#   copying pyarrow/conftest.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow
#   copying pyarrow/_generated_version.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow
#   copying pyarrow/benchmark.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow
#   copying pyarrow/_compute_docstrings.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow
#   copying pyarrow/ipc.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow
#   copying pyarrow/util.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow
#   copying pyarrow/flight.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow
#   copying pyarrow/cffi.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow
#   copying pyarrow/substrait.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow
#   copying pyarrow/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow
#   copying pyarrow/types.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow
#   copying pyarrow/dataset.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow
#   copying pyarrow/cuda.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow
#   copying pyarrow/feather.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow
#   copying pyarrow/pandas_compat.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow
#   copying pyarrow/fs.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow
#   copying pyarrow/acero.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow
#   copying pyarrow/csv.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow
#   copying pyarrow/jvm.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow
#   copying pyarrow/json.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow
#   copying pyarrow/compute.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow
#   creating build/lib.macosx-10.9-x86_64-cpython-38/examples/parquet_encryption
#   copying examples/parquet_encryption/sample_vault_kms_client.py -> build/lib.macosx-10.9-x86_64-cpython-38/examples/parquet_encryption
#   creating build/lib.macosx-10.9-x86_64-cpython-38/examples/dataset
#   copying examples/dataset/write_dataset_encrypted.py -> build/lib.macosx-10.9-x86_64-cpython-38/examples/dataset
#   creating build/lib.macosx-10.9-x86_64-cpython-38/examples/flight
#   copying examples/flight/server.py -> build/lib.macosx-10.9-x86_64-cpython-38/examples/flight
#   copying examples/flight/client.py -> build/lib.macosx-10.9-x86_64-cpython-38/examples/flight
#   copying examples/flight/middleware.py -> build/lib.macosx-10.9-x86_64-cpython-38/examples/flight
#   creating build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/tests
#   copying pyarrow/tests/test_tensor.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/tests
#   copying pyarrow/tests/test_ipc.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/tests
#   copying pyarrow/tests/test_flight_async.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/tests
#   copying pyarrow/tests/conftest.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/tests
#   copying pyarrow/tests/test_convert_builtin.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/tests
#   copying pyarrow/tests/test_misc.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/tests
#   copying pyarrow/tests/arrow_39313.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/tests
#   copying pyarrow/tests/arrow_16597.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/tests
#   copying pyarrow/tests/test_acero.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/tests
#   copying pyarrow/tests/test_gandiva.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/tests
#   copying pyarrow/tests/strategies.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/tests
#   copying pyarrow/tests/test_adhoc_memory_leak.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/tests
#   copying pyarrow/tests/arrow_7980.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/tests
#   copying pyarrow/tests/util.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/tests
#   copying pyarrow/tests/test_orc.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/tests
#   copying pyarrow/tests/test_table.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/tests
#   copying pyarrow/tests/test_array.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/tests
#   copying pyarrow/tests/test_deprecations.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/tests
#   copying pyarrow/tests/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/tests
#   copying pyarrow/tests/test_io.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/tests
#   copying pyarrow/tests/test_util.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/tests
#   copying pyarrow/tests/test_cuda_numba_interop.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/tests
#   copying pyarrow/tests/test_cpp_internals.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/tests
#   copying pyarrow/tests/test_cffi.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/tests
#   copying pyarrow/tests/test_schema.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/tests
#   copying pyarrow/tests/test_jvm.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/tests
#   copying pyarrow/tests/test_fs.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/tests
#   copying pyarrow/tests/test_udf.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/tests
#   copying pyarrow/tests/pandas_threaded_import.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/tests
#   copying pyarrow/tests/pandas_examples.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/tests
#   copying pyarrow/tests/test_cython.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/tests
#   copying pyarrow/tests/test_sparse_tensor.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/tests
#   copying pyarrow/tests/test_dataset.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/tests
#   copying pyarrow/tests/test_builder.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/tests
#   copying pyarrow/tests/test_dataset_encryption.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/tests
#   copying pyarrow/tests/test_cuda.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/tests
#   copying pyarrow/tests/test_extension_type.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/tests
#   copying pyarrow/tests/test_feather.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/tests
#   copying pyarrow/tests/test_pandas.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/tests
#   copying pyarrow/tests/test_memory.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/tests
#   copying pyarrow/tests/test_exec_plan.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/tests
#   copying pyarrow/tests/test_flight.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/tests
#   copying pyarrow/tests/test_device.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/tests
#   copying pyarrow/tests/read_record_batch.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/tests
#   copying pyarrow/tests/test_dlpack.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/tests
#   copying pyarrow/tests/test_json.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/tests
#   copying pyarrow/tests/test_compute.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/tests
#   copying pyarrow/tests/test_strategies.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/tests
#   copying pyarrow/tests/test_csv.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/tests
#   copying pyarrow/tests/test_scalars.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/tests
#   copying pyarrow/tests/test_gdb.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/tests
#   copying pyarrow/tests/test_types.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/tests
#   copying pyarrow/tests/test_substrait.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/tests
#   creating build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/interchange
#   copying pyarrow/interchange/from_dataframe.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/interchange
#   copying pyarrow/interchange/dataframe.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/interchange
#   copying pyarrow/interchange/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/interchange
#   copying pyarrow/interchange/buffer.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/interchange
#   copying pyarrow/interchange/column.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/interchange
#   creating build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/vendored
#   copying pyarrow/vendored/version.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/vendored
#   copying pyarrow/vendored/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/vendored
#   copying pyarrow/vendored/docscrape.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/vendored
#   creating build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/parquet
#   copying pyarrow/parquet/encryption.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/parquet
#   copying pyarrow/parquet/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/parquet
#   copying pyarrow/parquet/core.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/parquet
#   creating build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/tests/interchange
#   copying pyarrow/tests/interchange/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/tests/interchange
#   copying pyarrow/tests/interchange/test_conversion.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/tests/interchange
#   copying pyarrow/tests/interchange/test_interchange_spec.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/tests/interchange
#   creating build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/tests/parquet
#   copying pyarrow/tests/parquet/test_basic.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/tests/parquet
#   copying pyarrow/tests/parquet/conftest.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/tests/parquet
#   copying pyarrow/tests/parquet/encryption.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/tests/parquet
#   copying pyarrow/tests/parquet/test_parquet_writer.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/tests/parquet
#   copying pyarrow/tests/parquet/test_metadata.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/tests/parquet
#   copying pyarrow/tests/parquet/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/tests/parquet
#   copying pyarrow/tests/parquet/test_datetime.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/tests/parquet
#   copying pyarrow/tests/parquet/common.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/tests/parquet
#   copying pyarrow/tests/parquet/test_dataset.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/tests/parquet
#   copying pyarrow/tests/parquet/test_data_types.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/tests/parquet
#   copying pyarrow/tests/parquet/test_pandas.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/tests/parquet
#   copying pyarrow/tests/parquet/test_parquet_file.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/tests/parquet
#   copying pyarrow/tests/parquet/test_compliant_nested_type.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/tests/parquet
#   copying pyarrow/tests/parquet/test_encryption.py -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/tests/parquet
#   running egg_info
#   writing pyarrow.egg-info/PKG-INFO
#   writing dependency_links to pyarrow.egg-info/dependency_links.txt
#   writing requirements to pyarrow.egg-info/requires.txt
#   writing top-level names to pyarrow.egg-info/top_level.txt
#   <string>:34: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   ERROR setuptools_scm._file_finders.git listing git files failed - pretending there aren't any
#   reading manifest file 'pyarrow.egg-info/SOURCES.txt'
#   reading manifest template 'MANIFEST.in'
#   warning: no files found matching '../LICENSE.txt'
#   warning: no files found matching '../NOTICE.txt'
#   warning: no previously-included files matching '*.so' found anywhere in distribution
#   warning: no previously-included files matching '*.pyc' found anywhere in distribution
#   warning: no previously-included files matching '*~' found anywhere in distribution
#   warning: no previously-included files matching '#*' found anywhere in distribution
#   warning: no previously-included files matching '.git*' found anywhere in distribution
#   warning: no previously-included files matching '.DS_Store' found anywhere in distribution
#   no previously-included directories found matching '.asv'
#   writing manifest file 'pyarrow.egg-info/SOURCES.txt'
#   creating build/lib.macosx-10.9-x86_64-cpython-38/cmake_modules
#   copying cmake_modules/AWSSDKVariables.cmake -> build/lib.macosx-10.9-x86_64-cpython-38/cmake_modules
#   copying cmake_modules/BuildUtils.cmake -> build/lib.macosx-10.9-x86_64-cpython-38/cmake_modules
#   copying cmake_modules/DefineOptions.cmake -> build/lib.macosx-10.9-x86_64-cpython-38/cmake_modules
#   copying cmake_modules/FindAWSSDKAlt.cmake -> build/lib.macosx-10.9-x86_64-cpython-38/cmake_modules
#   copying cmake_modules/FindAzure.cmake -> build/lib.macosx-10.9-x86_64-cpython-38/cmake_modules
#   copying cmake_modules/FindBrotliAlt.cmake -> build/lib.macosx-10.9-x86_64-cpython-38/cmake_modules
#   copying cmake_modules/FindClangTools.cmake -> build/lib.macosx-10.9-x86_64-cpython-38/cmake_modules
#   copying cmake_modules/FindGTestAlt.cmake -> build/lib.macosx-10.9-x86_64-cpython-38/cmake_modules
#   copying cmake_modules/FindInferTools.cmake -> build/lib.macosx-10.9-x86_64-cpython-38/cmake_modules
#   copying cmake_modules/FindLLVMAlt.cmake -> build/lib.macosx-10.9-x86_64-cpython-38/cmake_modules
#   copying cmake_modules/FindOpenSSLAlt.cmake -> build/lib.macosx-10.9-x86_64-cpython-38/cmake_modules
#   copying cmake_modules/FindProtobufAlt.cmake -> build/lib.macosx-10.9-x86_64-cpython-38/cmake_modules
#   copying cmake_modules/FindPython3Alt.cmake -> build/lib.macosx-10.9-x86_64-cpython-38/cmake_modules
#   copying cmake_modules/FindRapidJSONAlt.cmake -> build/lib.macosx-10.9-x86_64-cpython-38/cmake_modules
#   copying cmake_modules/FindSQLite3Alt.cmake -> build/lib.macosx-10.9-x86_64-cpython-38/cmake_modules
#   copying cmake_modules/FindSnappyAlt.cmake -> build/lib.macosx-10.9-x86_64-cpython-38/cmake_modules
#   copying cmake_modules/FindThriftAlt.cmake -> build/lib.macosx-10.9-x86_64-cpython-38/cmake_modules
#   copying cmake_modules/Findc-aresAlt.cmake -> build/lib.macosx-10.9-x86_64-cpython-38/cmake_modules
#   copying cmake_modules/FindgRPCAlt.cmake -> build/lib.macosx-10.9-x86_64-cpython-38/cmake_modules
#   copying cmake_modules/FindgflagsAlt.cmake -> build/lib.macosx-10.9-x86_64-cpython-38/cmake_modules
#   copying cmake_modules/FindglogAlt.cmake -> build/lib.macosx-10.9-x86_64-cpython-38/cmake_modules
#   copying cmake_modules/FindjemallocAlt.cmake -> build/lib.macosx-10.9-x86_64-cpython-38/cmake_modules
#   copying cmake_modules/Findlibrados.cmake -> build/lib.macosx-10.9-x86_64-cpython-38/cmake_modules
#   copying cmake_modules/Findlz4Alt.cmake -> build/lib.macosx-10.9-x86_64-cpython-38/cmake_modules
#   copying cmake_modules/FindorcAlt.cmake -> build/lib.macosx-10.9-x86_64-cpython-38/cmake_modules
#   copying cmake_modules/Findre2Alt.cmake -> build/lib.macosx-10.9-x86_64-cpython-38/cmake_modules
#   copying cmake_modules/Findutf8proc.cmake -> build/lib.macosx-10.9-x86_64-cpython-38/cmake_modules
#   copying cmake_modules/FindzstdAlt.cmake -> build/lib.macosx-10.9-x86_64-cpython-38/cmake_modules
#   copying cmake_modules/GandivaAddBitcode.cmake -> build/lib.macosx-10.9-x86_64-cpython-38/cmake_modules
#   copying cmake_modules/SetupCxxFlags.cmake -> build/lib.macosx-10.9-x86_64-cpython-38/cmake_modules
#   copying cmake_modules/ThirdpartyToolchain.cmake -> build/lib.macosx-10.9-x86_64-cpython-38/cmake_modules
#   copying cmake_modules/UseCython.cmake -> build/lib.macosx-10.9-x86_64-cpython-38/cmake_modules
#   copying cmake_modules/Usevcpkg.cmake -> build/lib.macosx-10.9-x86_64-cpython-38/cmake_modules
#   copying cmake_modules/aws_sdk_cpp_generate_variables.sh -> build/lib.macosx-10.9-x86_64-cpython-38/cmake_modules
#   copying cmake_modules/san-config.cmake -> build/lib.macosx-10.9-x86_64-cpython-38/cmake_modules
#   copying cmake_modules/snappy.diff -> build/lib.macosx-10.9-x86_64-cpython-38/cmake_modules
#   copying pyarrow/__init__.pxd -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow
#   copying pyarrow/_acero.pxd -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow
#   copying pyarrow/_acero.pyx -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow
#   copying pyarrow/_azurefs.pyx -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow
#   copying pyarrow/_compute.pxd -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow
#   copying pyarrow/_compute.pyx -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow
#   copying pyarrow/_csv.pxd -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow
#   copying pyarrow/_csv.pyx -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow
#   copying pyarrow/_cuda.pxd -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow
#   copying pyarrow/_cuda.pyx -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow
#   copying pyarrow/_dataset.pxd -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow
#   copying pyarrow/_dataset.pyx -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow
#   copying pyarrow/_dataset_orc.pyx -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow
#   copying pyarrow/_dataset_parquet.pxd -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow
#   copying pyarrow/_dataset_parquet.pyx -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow
#   copying pyarrow/_dataset_parquet_encryption.pyx -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow
#   copying pyarrow/_dlpack.pxi -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow
#   copying pyarrow/_feather.pyx -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow
#   copying pyarrow/_flight.pyx -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow
#   copying pyarrow/_fs.pxd -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow
#   copying pyarrow/_fs.pyx -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow
#   copying pyarrow/_gcsfs.pyx -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow
#   copying pyarrow/_hdfs.pyx -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow
#   copying pyarrow/_json.pxd -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow
#   copying pyarrow/_json.pyx -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow
#   copying pyarrow/_orc.pxd -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow
#   copying pyarrow/_orc.pyx -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow
#   copying pyarrow/_parquet.pxd -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow
#   copying pyarrow/_parquet.pyx -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow
#   copying pyarrow/_parquet_encryption.pxd -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow
#   copying pyarrow/_parquet_encryption.pyx -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow
#   copying pyarrow/_pyarrow_cpp_tests.pxd -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow
#   copying pyarrow/_pyarrow_cpp_tests.pyx -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow
#   copying pyarrow/_s3fs.pyx -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow
#   copying pyarrow/_substrait.pyx -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow
#   copying pyarrow/array.pxi -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow
#   copying pyarrow/benchmark.pxi -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow
#   copying pyarrow/builder.pxi -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow
#   copying pyarrow/compat.pxi -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow
#   copying pyarrow/config.pxi -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow
#   copying pyarrow/device.pxi -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow
#   copying pyarrow/error.pxi -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow
#   copying pyarrow/gandiva.pyx -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow
#   copying pyarrow/io.pxi -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow
#   copying pyarrow/ipc.pxi -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow
#   copying pyarrow/lib.pxd -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow
#   copying pyarrow/lib.pyx -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow
#   copying pyarrow/memory.pxi -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow
#   copying pyarrow/pandas-shim.pxi -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow
#   copying pyarrow/public-api.pxi -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow
#   copying pyarrow/scalar.pxi -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow
#   copying pyarrow/table.pxi -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow
#   copying pyarrow/tensor.pxi -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow
#   copying pyarrow/types.pxi -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow
#   creating build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/includes
#   copying pyarrow/includes/common.pxd -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/includes
#   copying pyarrow/includes/libarrow_feather.pxd -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/includes
#   copying pyarrow/includes/libarrow_acero.pxd -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/includes
#   copying pyarrow/includes/libparquet_encryption.pxd -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/includes
#   copying pyarrow/includes/__init__.pxd -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/includes
#   copying pyarrow/includes/libgandiva.pxd -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/includes
#   copying pyarrow/includes/libarrow_python.pxd -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/includes
#   copying pyarrow/includes/libarrow_flight.pxd -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/includes
#   copying pyarrow/includes/libarrow_dataset_parquet.pxd -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/includes
#   copying pyarrow/includes/libarrow_dataset.pxd -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/includes
#   copying pyarrow/includes/libarrow_substrait.pxd -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/includes
#   copying pyarrow/includes/libarrow.pxd -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/includes
#   copying pyarrow/includes/libarrow_cuda.pxd -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/includes
#   copying pyarrow/includes/libarrow_fs.pxd -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/includes
#   copying pyarrow/tests/bound_function_visit_strings.pyx -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/tests
#   copying pyarrow/tests/extensions.pyx -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/tests
#   copying pyarrow/tests/pyarrow_cython_example.pyx -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/tests
#   creating build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/tests/data/feather
#   copying pyarrow/tests/data/feather/v0.17.0.version.2-compression.lz4.feather -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/tests/data/feather
#   creating build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/tests/data/orc
#   copying pyarrow/tests/data/orc/README.md -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/tests/data/orc
#   copying pyarrow/tests/data/orc/TestOrcFile.emptyFile.jsn.gz -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/tests/data/orc
#   copying pyarrow/tests/data/orc/TestOrcFile.emptyFile.orc -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/tests/data/orc
#   copying pyarrow/tests/data/orc/TestOrcFile.test1.jsn.gz -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/tests/data/orc
#   copying pyarrow/tests/data/orc/TestOrcFile.test1.orc -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/tests/data/orc
#   copying pyarrow/tests/data/orc/TestOrcFile.testDate1900.jsn.gz -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/tests/data/orc
#   copying pyarrow/tests/data/orc/TestOrcFile.testDate1900.orc -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/tests/data/orc
#   copying pyarrow/tests/data/orc/decimal.jsn.gz -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/tests/data/orc
#   copying pyarrow/tests/data/orc/decimal.orc -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/tests/data/orc
#   creating build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/tests/data/parquet
#   copying pyarrow/tests/data/parquet/v0.7.1.all-named-index.parquet -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/tests/data/parquet
#   copying pyarrow/tests/data/parquet/v0.7.1.column-metadata-handling.parquet -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/tests/data/parquet
#   copying pyarrow/tests/data/parquet/v0.7.1.parquet -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/tests/data/parquet
#   copying pyarrow/tests/data/parquet/v0.7.1.some-named-index.parquet -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/tests/data/parquet
#   creating build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/src/arrow/python
#   copying pyarrow/src/arrow/python/CMakeLists.txt -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/src/arrow/python
#   copying pyarrow/src/arrow/python/api.h -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/src/arrow/python
#   copying pyarrow/src/arrow/python/arrow_to_pandas.cc -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/src/arrow/python
#   copying pyarrow/src/arrow/python/arrow_to_pandas.h -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/src/arrow/python
#   copying pyarrow/src/arrow/python/arrow_to_python_internal.h -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/src/arrow/python
#   copying pyarrow/src/arrow/python/async.h -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/src/arrow/python
#   copying pyarrow/src/arrow/python/benchmark.cc -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/src/arrow/python
#   copying pyarrow/src/arrow/python/benchmark.h -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/src/arrow/python
#   copying pyarrow/src/arrow/python/common.cc -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/src/arrow/python
#   copying pyarrow/src/arrow/python/common.h -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/src/arrow/python
#   copying pyarrow/src/arrow/python/csv.cc -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/src/arrow/python
#   copying pyarrow/src/arrow/python/csv.h -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/src/arrow/python
#   copying pyarrow/src/arrow/python/datetime.cc -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/src/arrow/python
#   copying pyarrow/src/arrow/python/datetime.h -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/src/arrow/python
#   copying pyarrow/src/arrow/python/decimal.cc -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/src/arrow/python
#   copying pyarrow/src/arrow/python/decimal.h -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/src/arrow/python
#   copying pyarrow/src/arrow/python/deserialize.cc -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/src/arrow/python
#   copying pyarrow/src/arrow/python/deserialize.h -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/src/arrow/python
#   copying pyarrow/src/arrow/python/extension_type.cc -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/src/arrow/python
#   copying pyarrow/src/arrow/python/extension_type.h -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/src/arrow/python
#   copying pyarrow/src/arrow/python/filesystem.cc -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/src/arrow/python
#   copying pyarrow/src/arrow/python/filesystem.h -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/src/arrow/python
#   copying pyarrow/src/arrow/python/flight.cc -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/src/arrow/python
#   copying pyarrow/src/arrow/python/flight.h -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/src/arrow/python
#   copying pyarrow/src/arrow/python/gdb.cc -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/src/arrow/python
#   copying pyarrow/src/arrow/python/gdb.h -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/src/arrow/python
#   copying pyarrow/src/arrow/python/helpers.cc -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/src/arrow/python
#   copying pyarrow/src/arrow/python/helpers.h -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/src/arrow/python
#   copying pyarrow/src/arrow/python/inference.cc -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/src/arrow/python
#   copying pyarrow/src/arrow/python/inference.h -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/src/arrow/python
#   copying pyarrow/src/arrow/python/init.cc -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/src/arrow/python
#   copying pyarrow/src/arrow/python/init.h -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/src/arrow/python
#   copying pyarrow/src/arrow/python/io.cc -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/src/arrow/python
#   copying pyarrow/src/arrow/python/io.h -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/src/arrow/python
#   copying pyarrow/src/arrow/python/ipc.cc -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/src/arrow/python
#   copying pyarrow/src/arrow/python/ipc.h -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/src/arrow/python
#   copying pyarrow/src/arrow/python/iterators.h -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/src/arrow/python
#   copying pyarrow/src/arrow/python/numpy_convert.cc -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/src/arrow/python
#   copying pyarrow/src/arrow/python/numpy_convert.h -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/src/arrow/python
#   copying pyarrow/src/arrow/python/numpy_internal.h -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/src/arrow/python
#   copying pyarrow/src/arrow/python/numpy_interop.h -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/src/arrow/python
#   copying pyarrow/src/arrow/python/numpy_to_arrow.cc -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/src/arrow/python
#   copying pyarrow/src/arrow/python/numpy_to_arrow.h -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/src/arrow/python
#   copying pyarrow/src/arrow/python/parquet_encryption.cc -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/src/arrow/python
#   copying pyarrow/src/arrow/python/parquet_encryption.h -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/src/arrow/python
#   copying pyarrow/src/arrow/python/pch.h -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/src/arrow/python
#   copying pyarrow/src/arrow/python/platform.h -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/src/arrow/python
#   copying pyarrow/src/arrow/python/pyarrow.cc -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/src/arrow/python
#   copying pyarrow/src/arrow/python/pyarrow.h -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/src/arrow/python
#   copying pyarrow/src/arrow/python/pyarrow_api.h -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/src/arrow/python
#   copying pyarrow/src/arrow/python/pyarrow_lib.h -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/src/arrow/python
#   copying pyarrow/src/arrow/python/python_test.cc -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/src/arrow/python
#   copying pyarrow/src/arrow/python/python_test.h -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/src/arrow/python
#   copying pyarrow/src/arrow/python/python_to_arrow.cc -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/src/arrow/python
#   copying pyarrow/src/arrow/python/python_to_arrow.h -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/src/arrow/python
#   copying pyarrow/src/arrow/python/serialize.cc -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/src/arrow/python
#   copying pyarrow/src/arrow/python/serialize.h -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/src/arrow/python
#   copying pyarrow/src/arrow/python/type_traits.h -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/src/arrow/python
#   copying pyarrow/src/arrow/python/udf.cc -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/src/arrow/python
#   copying pyarrow/src/arrow/python/udf.h -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/src/arrow/python
#   copying pyarrow/src/arrow/python/visibility.h -> build/lib.macosx-10.9-x86_64-cpython-38/pyarrow/src/arrow/python
#   running build_ext
#   creating /private/var/folders/30/n6z5zgm17kx9ygm_fjmcvg000000gn/T/pip-install-jorszxx8/pyarrow_9979dd1976b9448e82f7ea6f6650732c/build/temp.macosx-10.9-x86_64-cpython-38
#   -- Running cmake for PyArrow
#   cmake -DCMAKE_INSTALL_PREFIX=/private/var/folders/30/n6z5zgm17kx9ygm_fjmcvg000000gn/T/pip-install-jorszxx8/pyarrow_9979dd1976b9448e82f7ea6f6650732c/build/lib.macosx-10.9-x86_64-cpython-38/pyarrow -DPYTHON_EXECUTABLE=/Users/johnjordan/opt/anaconda3/bin/python -DPython3_EXECUTABLE=/Users/johnjordan/opt/anaconda3/bin/python -DPYARROW_CXXFLAGS= -DPYARROW_BUNDLE_ARROW_CPP=off -DPYARROW_BUNDLE_CYTHON_CPP=off -DPYARROW_GENERATE_COVERAGE=off -DCMAKE_BUILD_TYPE=release /private/var/folders/30/n6z5zgm17kx9ygm_fjmcvg000000gn/T/pip-install-jorszxx8/pyarrow_9979dd1976b9448e82f7ea6f6650732c
#   error: command 'cmake' failed: No such file or directory
#   ----------------------------------------
#   ERROR: Failed building wheel for pyarrow
# Failed to build pyarrow
# ERROR: Could not build wheels for pyarrow which use PEP 517 and cannot be installed directly
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
import streamlit as st
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-15-5425d929a889> in <module>
#       1 import requests
# ----> 2 import streamlit as st
#
# ModuleNotFoundError: No module named 'streamlit'

# %%
remedy_counts = df['remedy'].value_counts()
remedy_counts
# Out:
# remedy
#                               66
# [Repair]                       9
# [Replace]                      8
# [Refund]                       5
# [Replace, Refund]              1
# [Refund, Repair]               1
# [New Instructions, Repair]     1
# Name: count, dtype: int64

# %%
# Create streamlit output:
st.title('Remedy Statistics')
st.write(remedy_counts)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-f48157707162> in <module>
#       1 # Create streamlit output:
# ----> 2 st.title('Remedy Statistics')
#       3 st.write(remedy_counts)
#
# NameError: name 'st' is not defined

# %% [markdown]
# ## Other API Sources
#
# Valuable and interesting Federal API resources are listed at:
#
#     https://catalog.data.gov/dataset/?_res_format_limit=0&res_format=API
#
# and in the future will likely easily be found at \texttt{data.gov}. Some highlights include:
#
# - CDC WONDER API for Data Query Web Service: Includes death certificates with causes since approximately the 1990's.
# - Comprehensive Housing Affordability Strategy (CHAS): Housing and Urban Development (HUD) maintains an API that provides Census data on housing problems and needs unavailable through other sources, including IPUMS.
# - Federal Election Commission API: Provides historical and up to the minute campaign finance data.
# - Toxic Release Inventory: Provided by the Environmental Protection Agency, this API documents the release and management of over 800 toxic substances, reported annually by privately owned facilities and the government.
# - Petroleum Data, Prices: Provides prices of petroleum products and crude oil at weekly, monthly, and yearly time scales.
# - Fair Market Rents Lookup tool: Fair Market Rents (FMRs) determine the value of housing vouchers for Section 8 renters. This API provides the FMR values and other measures of housing affordability.
# - Annual Economic Surveys, Business Patterns: Surveys of businesses at the zip code level, tracking economic sentiment and activity.
# - Food Access Research Atlas: Provides spatial data on food access and the availability of supermarkets within census tracts. Can be merged with census data to look at under-served populations and food deserts.
# - National Oceanographic and Atmospheric Administration: Provides API access to data on real time weather and climate change projections.
#
# Each of these API resources could either be the cornerstone of a project or a source of additional data. These data sources have a number of advantages: They're free, most of them can be accessed using the same API key, and most have similar documentation for how to write a query. This is ideal for students to iterate, experiment, and take risks, with little cost to failure.
#
# In addition to government data, many commerical apps provide API access to developers and researchers. AirBnB, Amazon, Reddit, eBay, X, and many others maintain API access to develop third-party apps. These opportunities present many advantages: The data are larger, have more variety, and there are vastly many more cases. Building a third-party app that includes analytics could easily consume an entire semester and open a variety of applications in predictive analytics, natural language processing, and generative AI (e.g. predict which reviews are fake or real for Amazon for a product group like ``women's watches', and then make recommendations for different price points). While an exciting possibility, this can also raise a lot of problems: Some API's cost money or are rate-limited depending on a subscription, and others impose significant constraints on how the data can be used. In some cases, a more useful approach might be explicit web scraping using a package like BeautifulSoup or Selenium. For example, Craigslist has no API, but can easily and productively be scraped using BeautifulSoup.
#
# **5. Pick an API, download some data, wrangle them, and produce some EDA results, as we did in the previous steps with the saferproducts.gov API; or, if you can't get it to work, document why. If you have the time and it's low cost, push the results to a streamlit page. If you have had enough, I recommend https://www.eia.gov/opendata/browser/electricity, since there is a friendly query builder that you can use to learn.**

# %% [markdown]
# Basic Plots(using sns)
#     - Histogram
#     - Density
#     - Boxplot
#     - Scatterplot
